# %%
import tokenize
#import seulin
from crawling import getText, getOneText

users = getText('http://114.71.103.80/new_db.php?q=select+*+from+users%0D%0Alimit+200%0D%0A%0D%0A', '1')

del users[0]

# %%
import tokenize, suji
from itertools import tee

def calc_Aver(user, problems):
    print('------', user, '----problem number:',len(problems), '----------------')
#     res = func_Return_Aver(problems)
    res = func_Length_Aver(problems)
    print(res)
    return res
    #print(round(func_Number_Aver(bundle), 5), '\t\t', round(funcParam_Number_Aver(bundle), 5))
#     print('func number:', round(func_Number_Aver(bundle), 5))
#     print('func param number:', round(funcParam_Number_Aver(bundle), 5))


def func_Number_Aver(bundle):
    #tokens = list of tokens
    result = 0
    for tokens in bundle:
        result += func_Number(tokens)
    return result / len(bundle)

def funcParam_Number_Aver(bundle):
    result = 0
    for tokens in bundle:
        lst = funcParam_Number(tokens)
        if len(lst) > 0:
            result += sum(lst) / len(lst)
    return result / len(bundle)

def func_Return_Aver(bundle):
    result = [0, 0, 0]
    for tokens in bundle:
        lst = func_Return(tokens)
        for i in range(3):
            result[i] += lst[i]
    return result

def tree_height_Aver(bundle):
    result = [0, 0]
    for tokens in bundle:
        root = check_structure(tokens)
        result[0] += root.height
        
    for leaf in root.leaves:
        count = 0
        for node in leaf.iter_path_reverse():
            if node.name == 'for':
                count += 1
        if count > 1:
            result[1] += 1
        
    result[0] /= len(bundle)
    result[1] /= len(bundle)
    return result

def func_Length_Aver(bundle):
    result = 0
    for tokens in bundle:
        root = check_structure(tokens)
        for node in PreOrderIter(root):
            if node.name == 'def':
                result += suji.Total_Line(tokens[node.index[0]:node.index[1]])
    return result / len(bundle)

# %%
final = []

for user in users:
    problems = getText('http://114.71.103.80/new_db.php?q=select+*+from+code_submission+c%2C+%28select+id%2C+max%28regtime%29+a+from+code_submission+where+id+%3D+'+ user +'++group+by+p_no%29+d+where+c.id+%3D+d.id+and+d.a+%3D+c.regtime+',  '4')
    num = 0
    bundle = []
    for prob in problems:
        num += 1
        with open('hello.py', 'wb+') as fw:
            fw.write(prob.encode('utf-8'))

        with open('hello.py', 'rb') as fr:
            try:
                bundle.append(list(tokenize.tokenize(fr.readline)))
            # tokens = tokenize.generate_tokens(f.readline)
            # pf.check_token(tokens)
            except:
                pass
                #print('ERROR IN CODE')
    #break # for scientific writing
#     try:
    if len(bundle) > 0:
        res = calc_Aver(user, bundle)
        final.append(res)
    else:
        print(f'{user}: Empty problems(submissions)')
        #print(pf.C_codingstyle_Preference(tokens), num)
#     except:    # 예외가 발생했을 때 실행됨
#         print('@', e)
                

# with open('hello.py', 'rb') as f:
#     tokens = tokenize.tokenize(f.readline)

# with open('hello.py', 'rb') as f:
#     tokens = tokenize.tokenize(f.readline)
#     for tok in tokens:
#         print(tokenize.tok_name[tok.type],
#               tokenize.tok_name[tok.exact_type], repr(tok.string))


# import tokenize
# import preference as pf
# from crawling import getText, getOneText


# with open('hello.py', 'rb') as f:
#     tokens = tokenize.tokenize(f.readline)
#     print(pf.C_codingstyle_Preference(tokens))
# Out:
# ------ 201411023 ----problem number: 54 ----------------
# 6.925925925925926
# ------ 201411085 ----problem number: 76 ----------------
# 10.802631578947368
# ------ 201411130 ----problem number: 61 ----------------
# 13.360655737704919
# ------ 201411153 ----problem number: 58 ----------------
# 10.96551724137931
# ------ 201511020 ----problem number: 62 ----------------
# 8.35483870967742
# ------ 201511057 ----problem number: 69 ----------------
# 12.173913043478262
# ------ 201511080 ----problem number: 62 ----------------
# 20.306451612903224
# ------ 201511153 ----problem number: 71 ----------------
# 11.647887323943662
# ------ 201611074 ----problem number: 64 ----------------
# 11.328125
# 201611101: Empty problems(submissions)
# ------ 201611104 ----problem number: 71 ----------------
# 10.873239436619718
# ------ 201611155 ----problem number: 69 ----------------
# 10.898550724637682
# ------ 201611161 ----problem number: 72 ----------------
# 10.76388888888889
# ...

# %% [markdown]
# import pandas as pd
# import numpy as np
#
# print(save)
# df = pd.DataFrame(save, columns=['return None', 'return', '@'])
#
# df['new'] = df['@'] >= 0
# df.head()
# a = df.groupby('new')
# a.size()

# %%
from anytree import Node, RenderTree, PreOrderIter


def check_structure(tokens):
        root = Node('root', index = [0, len(tokens) - 1], pos = -1)
        keyword = ['if', 'elif', 'else', 'while', 'for', 'def', 'class'] #keywords demanding indent
        stack = [root]
        cur_pos = 0
        
        def parenting(stack, index):
            node = stack.pop()
            node.index[1] = index
            node.parent = stack[-1]
        
        for (i, tok) in enumerate(tokens):
            if tokenize.tok_name[tok.type] == "NAME" and tok.string in keyword:
                node = Node(tok.string, index = [i, -1], pos = cur_pos)
                stack.append(node)
            elif tokenize.tok_name[tok.type] == "INDENT":
                cur_pos += 1
            elif tokenize.tok_name[tok.type] == 'DEDENT':
                cur_pos -= 1
                if stack[-1].pos == cur_pos:
                    parenting(stack, i)
                else:
                    pass
#                     print(stack[-1].pos, cur_pos)
#                     print('else case, not printed')

                # ex) if True: print(30)
            elif tokenize.tok_name[tok.exact_type] == 'COLON' and \
                tokens[i+1].type != 4: #means NEWLINE
                if stack[-1].pos == cur_pos:
                    parenting(stack, i)
                
                # [i for i in range(3)] @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@this case must be added
                # 30 if True else -30
                
        return root

# %%
import hello

hello.run()
with open('hello.py', 'rb') as f:
    tokens = list(tokenize.tokenize(f.readline))
for i in tokens:
    print(i)
# Out:
# print
# TokenInfo(type=57 (ENCODING), string='utf-8', start=(0, 0), end=(0, 0), line='')
# TokenInfo(type=1 (NAME), string='def', start=(1, 0), end=(1, 3), line='def find_max(t, l, r):\n')
# TokenInfo(type=1 (NAME), string='find_max', start=(1, 4), end=(1, 12), line='def find_max(t, l, r):\n')
# TokenInfo(type=53 (OP), string='(', start=(1, 12), end=(1, 13), line='def find_max(t, l, r):\n')
# TokenInfo(type=1 (NAME), string='t', start=(1, 13), end=(1, 14), line='def find_max(t, l, r):\n')
# TokenInfo(type=53 (OP), string=',', start=(1, 14), end=(1, 15), line='def find_max(t, l, r):\n')
# TokenInfo(type=1 (NAME), string='l', start=(1, 16), end=(1, 17), line='def find_max(t, l, r):\n')
# TokenInfo(type=53 (OP), string=',', start=(1, 17), end=(1, 18), line='def find_max(t, l, r):\n')
# TokenInfo(type=1 (NAME), string='r', start=(1, 19), end=(1, 20), line='def find_max(t, l, r):\n')
# TokenInfo(type=53 (OP), string=')', start=(1, 20), end=(1, 21), line='def find_max(t, l, r):\n')
# ...

# %%
import tokenize

with open('hello.py', 'rb') as f:
    tokens = list(tokenize.tokenize(f.readline))
    root = check_structure(tokens)
    
for leaf in root.leaves:
    count = 0
    for node in leaf.iter_path_reverse():
        if node.name == 'if':
            count += 1
    if count > 1:
        print(count)
        
for pre, fill, node in RenderTree(root):
    print("%s%s" % (pre, node.name))

#     print(func_Return(tokens))
    #print(funcParam_Number(tokens))
# Out:
# 3
# 2
# root
# ├── def
# │   └── for
# │       └── if
# │           └── if
# │               └── if
# │                   └── for
# ├── if
# │   └── if
# └── def
#     └── if

# %%
def func_Number(tokens):
    result = 0
    for tok in tokens:
        if tokenize.tok_name[tok.type] == 'NAME' and tok.string == 'def':
            result += 1
    return result

def funcParam_Number(tokens):
    tokens, tokens_copy = tee(tokens)
    result = [ 0 for i in range(func_Number(tokens_copy))]
#     def_line = ""
    
#     def generator():
#         yield def_line
#     gen = generator()
        
#     def getLine():
#         return next(gen)

    checkOn = False
    func_index = -1
    for tok in tokens:
        if tokenize.tok_name[tok.type] == 'NAME' and tok.string == 'def':
            checkOn = True
            func_index += 1
        elif tokenize.tok_name[tok.exact_type] == 'COLON':
            checkOn = False
        elif checkOn and tokenize.tok_name[tok.type] == "NAME":
            result[func_index] += 1
            
    for (i, v) in enumerate(result):
        result[i] -= 1 # subtract for removing function_name count
        
#             def_line = tok.line
#             def_tokens = tokenize.generate_tokens(getLine)
#             print(tok)
#             for piece in def_tokens:
#                 print(piece)
#                 if checkOn and tokenize.tok_name[piece.type] == "NAME":
#                     result[func_index] += 1
#                 elif tokenize.tok_name[piece.exact_type] == "LPAR":
#                     checkOn = True
#                 elif tokenize.tok_name[piece.exact_type] == "RPAR":
#                     checkOn = False
#                     break
    return result

def func_Return(tokens):
    num_def = 0
    num_return = 0
    result = [0, 0] # return / return None
    for tok in tokens:
        if tokenize.tok_name[tok.type] == 'NAME' and tok.string == 'def':
            num_def += 1 # not used
        elif tokenize.tok_name[tok.type] == 'NAME' and tok.string == 'return':
            num_return += 1
            index = tok.line.find('return')
            line = tok.line[:index] + tok.line[index + 6:]
            if 'None' in line:
                result[1] += 1
            elif line.isspace():
                result[0] += 1
#     result[2] = num_def - num_return
    return result

def func_Length(tokens):
    root = check_structure(tokens)
    result = []
    for node in PreOrderIter(root):
        if node.name == 'def':
            result.append(suji.Total_Line(tokens[node.index[0]:node.index[1]]))
    return sum(result) / len(result)

def tree_height(tokens):
    root = check_structure(tokens)
    return root.height

def nested(tokens, keyword):
    root = check_structure(tokens)
    count = [] # 중복된 횟수 (ex. 2 2 3 4)
    for i, leaf in enumerate(root.leaves):
        count.append(0)
        for node in leaf.iter_path_reverse():
            if node.name == keyword:
                count[i] += 1
    print(count)
    nested_only = [val for val in count if val not in (0, 1)]
    nested2 = nested_only.count(2)
    res = [nested2, len(nested_only) - nested2]
    res.append(res[0] + res[1])
    return res # 2개 중복 개수, 3개 이상 중복 개수, 총합
            
def nested_if(tokens):
    return nested(tokens, 'if')

def nested_for(tokens):
    return nested(tokens, 'for')
    
nested_for(tokens)
# Out:
# [2, 0, 0]
# [1, 0]

# %% [markdown]
# def getKeyword_Tokens(keyword, tokens):
#     #첫번째로 등장하는 키워드의 토큰묶음
#     nested = [] #next keyword appearnace
#     index = [0, 0] #index of tokens
#     keyword_pos = 0
#     checkOn = False
#     cur_pos = 0 #indent position
#     for i, tok in enumerate(tokens):
#         if tokenize.tok_name[tok.type] == 'NAME' and tok.string == keyword:
#             if not checkOn:
#                 checkOn = True
#                 keyword_pos = cur_pos
#                 index[0] = i
#             else:
#                 nested = tokens[i:]
#         elif checkOn and tokenize.tok_name[tok.type] == "INDENT":
#             #pre_pos = cur_pos
#             cur_pos += 1
#         elif checkOn and tokenize.tok_name[tok.type] == "DEDENT":
#             #pre_pos = cur_pos
#             cur_pos -= 1
#             if cur_pos == keyword_pos: #comeback
#                 checkOn = False
#                 index[1] = i
#                 return tokens[index[0]:index[1]]
# #         elif checkOn and tokenize.tok_name[tok.type] in ["NEWLINE", 'NL']
# #             checkOn += 1
#
#
# import suji
#
# def keyword_Length(keyword, tokens):
#
#     while tokens
#         target    = getKeyword_Tokens(keyword, tokens)
#
#         suji.Total_Line(target)
#
# def def_Length(tokens):
#     return keyword_Length('def', tokens)
#
# def for_Length(tokens):
#     return keyword_Length('for', tokens)
#
# def if_Length(tokens):
#     return keyword_Length('if', tokens)

# %% [markdown]
# #https://developer.rhino3d.com/guides/rhinopython/python-statements/
# #여러 줄에 걸쳐서 코드 하나 => 다른 토큰은 괜찮으나 string에서 \까지 그대로 읽는 문제 있음
# #한 줄에 여러 코드 적는 경우 => semicolone 있는 것에 유의
#
# message\
# =\
# 'This \
# back slash \
# acts \
# like \
# enter'
# print(\
# message)
# print('This \\\nback slash \\\nacts \\\nlike \\\nenter')
#
# y = 3; x = 5; print(x+y);
